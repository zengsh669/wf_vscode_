# %%
# pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from seaborn) (1.23.5)
# Requirement already satisfied: pandas>=1.2 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from seaborn) (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyodbc
import pandas as pd
from azure.identity import DefaultAzureCredential
from azure.keyvault.secrets import SecretClient
from datetime import datetime, timedelta

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def get_secret():
    credential = DefaultAzureCredential()
    secret_client = SecretClient(vault_url="https://kvsynapsedata001.vault.azure.net", credential=credential)
    secret = secret_client.get_secret("pw-SRVSQLPoolSQL")
    return secret.value
 
 
server = 'tcp:arriba-synapseworkspace-prod-ae-001.sql.azuresynapse.net,1433'
database = 'arribasqlpool1'
username = 'SRV_SQLPool_SQL'
password = get_secret()  
 
otheropts = 'Encrypt=yes;TrustServerCertificate=yes;Connection Timeout=30;'
 
 
cnxn_t = pyodbc.connect('DRIVER={ODBC Driver 18 for SQL Server};SERVER='+server+';DATABASE='+database+';UID='+username+';PWD='+password+';'+otheropts)
cursor_t = cnxn_t.cursor()

# %% [markdown]
# ##### Sample Queries

# %% [markdown]
# ##### AB tables from JRL

# %%
queries = {
    "df_emp_df": "SELECT * FROM [df].[EmployeeInfo]",
    "df_leave_df": "SELECT * FROM [df].[EmployeeLeaves]"
}

# 执行查询并存入字典
dfs = {name: pd.read_sql(query, cnxn_t) for name, query in queries.items()}

# 保存文件
for name, df in dfs.items():
    csv_filename = name.replace("_df", "") + ".csv"
    df.to_csv(csv_filename, index=False)


print("所有 DataFrame 已保存为 csv 文件。")
# Out:
# /tmp/ipykernel_10415/3588252097.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dfs = {name: pd.read_sql(query, cnxn_t) for name, query in queries.items()}
# /tmp/ipykernel_10415/3588252097.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dfs = {name: pd.read_sql(query, cnxn_t) for name, query in queries.items()}
# 所有 DataFrame 已保存为 csv 文件。

# %%
leave_ = pd.read_csv("df_leave.csv")
emp_= pd.read_csv("df_emp.csv")

# %%
emp_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1113 entries, 0 to 1112
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   EmployeeNumber     1113 non-null   int64
#  1   FirstName          1113 non-null   object
#  2   MiddleName         503 non-null    object
#  3   LastName           1113 non-null   object
#  4   CommonName         689 non-null    object
#  5   PreferredLastName  110 non-null    object
#  6   FederatedId        1075 non-null   object
#  7   BirthDate          1113 non-null   object
#  8   StartDate          1113 non-null   object
#  9   OriginalHireDate   1113 non-null   object
#  10  TerminationDate    498 non-null    object
#  11  Pronouns           1113 non-null   object
#  12  GenderIdentity     1014 non-null   object
# dtypes: int64(1), object(12)
# memory usage: 113.2+ KB

# %%
def check_and_set_index(df, column_name):
    # 检查重复值
    duplicates = df[column_name][df[column_name].duplicated(keep=False)]
    
    if duplicates.empty:
        df = df.set_index(column_name)
        print(f"No duplicates found. '{column_name}' has been set as index.")
        return df
    else:
        dup_counts = df[column_name].value_counts()
        dup_filtered = dup_counts[dup_counts > 1]
        print(f"Found duplicates in '{column_name}':")
        print(dup_filtered)
        return df  # 保持原样，不设置 index

# 使用方法
emp_ = check_and_set_index(emp_, 'EmployeeNumber')
# Out:
# No duplicates found. 'EmployeeNumber' has been set as index.

# %%
emp_
# Out:
#                 FirstName MiddleName        LastName CommonName  \
# EmployeeNumber
# 80277           Alexandra        NaN         Barnard       Ally
# 80191           Tracy-Lee        NaN           Lucas      Tracy
# 80941                 Emy        NaN             Liu        NaN
# 80883              Hayley     Louise        Vallance        NaN
# 80323              Joanne      Marie          Crerar     Joanne
# ...                   ...        ...             ...        ...
# 81046              Dimity        NaN           Hicks        NaN
# 80727              Kethya    Hirushi  Wickramanayake       Keth
# 81056                 Lin        NaN             Foo        NaN
# 80085              Hajara        NaN           Diyab     Hajara
# 59810            Savannah        NaN          Webeck        NaN
#
#                PreferredLastName                             FederatedId  \
# EmployeeNumber
# 80277                        NaN         abarnard@rehabmanagement.com.au
# 80191                        NaN           tlucas@rehabmanagement.com.au
# 80941                        NaN             eliu@rehabmanagement.com.au
# 80883                        NaN        hvallance@rehabmanagement.com.au
# 80323                        NaN          JCrerar@rehabmanagement.com.au
# ...                          ...                                     ...
# 81046                        NaN                                     NaN
# 80727                        NaN  kwickramanayake@rehabmanagement.com.au
# 81056                        NaN             lfoo@rehabmanagement.com.au
# 80085                        NaN                   HDiyab@livebig.com.au
# 59810                        NaN                  SWebeck@livebig.com.au
#
#                           BirthDate            StartDate     OriginalHireDate  \
# EmployeeNumber
# 80277           1998-07-24T00:00:00  2021-06-07T00:00:00  2021-06-07T00:00:00
# 80191           1980-05-14T00:00:00  2016-08-15T00:00:00  2016-08-15T00:00:00
# 80941           1994-12-09T00:00:00  2025-02-03T00:00:00  2025-02-03T00:00:00
# 80883           1993-05-30T00:00:00  2024-12-02T00:00:00  2024-12-02T00:00:00
# 80323           1974-08-15T00:00:00  2022-04-04T00:00:00  2022-04-04T00:00:00
# ...                             ...                  ...                  ...
# 81046           1900-01-01T00:00:00  2025-04-28T00:00:00  2025-04-28T00:00:00
# 80727           2001-02-06T00:00:00  2024-08-05T00:00:00  2024-08-05T00:00:00
# 81056           2002-09-30T00:00:00  2025-04-28T00:00:00  2025-04-28T00:00:00
# 80085           1996-03-12T00:00:00  2023-08-21T00:00:00  2023-08-21T00:00:00
# 59810           1900-01-01T00:00:00  2021-11-16T00:00:00  2021-11-16T00:00:00
#
#                     TerminationDate               Pronouns GenderIdentity
# EmployeeNumber
# 80277           2025-07-11T23:59:00      Alexandra Barnard         Female
# 80191                           NaN        Tracy-Lee Lucas         Female
# 80941                           NaN                Emy Liu         Female
# 80883                           NaN        Hayley Vallance         Female
# 80323                           NaN          Joanne Crerar         Female
# ...                             ...                    ...            ...
# 81046                           NaN           Dimity Hicks            NaN
# 80727           2024-09-26T23:59:00  Kethya Wickramanayake         Female
# 81056           2025-07-04T23:59:00                Lin Foo            NaN
# 80085           2024-12-03T23:59:00           Hajara Diyab         Female
# 59810           2021-11-16T23:59:00        Savannah Webeck            NaN
#
# [1113 rows x 12 columns]

# %%
# 过滤包含 Dominique 或 O’Connell 的行
filtered_emp = emp_[emp_['Pronouns'].str.contains("Dominique|O'Connell", case=False, na=False)]

# 显示结果
filtered_emp.reset_index(inplace=True)

# %%
leave_.head()
# Out:
#    EmployeeNumber        DateofRequest            TimeStart  \
# 0           80949  2025-07-02T12:21:00  2025-07-01T02:30:00
# 1           60030  2025-06-24T11:01:00  2025-06-27T12:00:00
# 2           80388  2025-06-24T11:02:00  2025-07-03T00:00:00
# 3           80842  2025-06-26T15:37:00  2025-06-26T09:00:00
# 4           60077  2025-06-24T11:01:00  2025-06-26T14:00:00
#
#                TimeEnd                           TAFWXRefCode  \
# 0  2025-07-01T05:00:00                                    NaN
# 1  2025-06-27T17:00:00  60030_ANNUAL_LEAVE_HOURS_202506271200
# 2  2025-07-05T00:00:00  80388_ANNUAL_LEAVE_HOURS_202507030000
# 3  2025-06-26T13:00:00                                    NaN
# 4  2025-06-26T17:00:00  60077_ANNUAL_LEAVE_HOURS_202506261400
#
#                    LeaveType  NetHours AllDay
# 0  AU Sick and Carer's Leave       2.5    NaN
# 1            AU Annual Leave       4.1    NaN
# 2            AU Annual Leave      15.2   True
# 3  AU Sick and Carer's Leave       4.0    NaN
# 4            AU Annual Leave       3.0    NaN

# %%
leave_filtered = leave_[leave_['EmployeeNumber'].isin(filtered_emp['EmployeeNumber'])].merge(
    filtered_emp[['EmployeeNumber', 'Pronouns']], on='EmployeeNumber'
).rename(columns={'Pronouns': 'Full Name'})

# %%
leave_filtered
# Out:
#    EmployeeNumber        DateofRequest            TimeStart  \
# 0           80832  2025-06-25T12:56:00  2025-06-25T08:30:00
# 1           80832  2025-07-01T07:42:00  2025-09-15T00:00:00
# 2           80832  2025-07-09T09:39:00  2025-07-07T00:00:00
# 3           80832  2025-07-11T09:32:00  2025-11-14T00:00:00
# 4           80832  2025-07-16T17:08:00  2025-08-08T00:00:00
# 5           80185  2025-06-24T11:01:00  2025-06-27T00:00:00
# 6           80185  2025-07-21T10:25:00  2025-11-04T00:00:00
# 7           80185  2025-07-21T10:27:00  2025-08-08T00:00:00
# 8           80185  2025-07-21T10:30:00  2025-10-24T00:00:00
# 9           80185  2025-07-23T08:51:00  2025-07-22T13:00:00
#
#                TimeEnd                TAFWXRefCode  \
# 0  2025-06-25T11:00:00                         NaN
# 1  2025-09-20T00:00:00                         NaN
# 2  2025-07-09T00:00:00                         NaN
# 3  2025-11-22T00:00:00                         NaN
# 4  2025-08-09T00:00:00                         NaN
# 5  2025-06-28T00:00:00  80185_YOU_DAY_202506270000
# 6  2025-11-12T00:00:00                         NaN
# 7  2025-08-09T00:00:00                         NaN
# 8  2025-10-25T00:00:00                         NaN
# 9  2025-07-22T16:30:00                         NaN
#
#                           LeaveType  NetHours AllDay          Full Name
# 0         AU Sick and Carer's Leave       2.5    NaN   Hannah O'Connell
# 1  AU Unpaid Sick and Carer's Leave      38.0   True   Hannah O'Connell
# 2       AU Mandatory Training Leave      15.2   True   Hannah O'Connell
# 3                   AU Annual Leave      45.6   True   Hannah O'Connell
# 4                        AU You Day       7.6   True   Hannah O'Connell
# 5                        AU You Day       7.6   True  Dominique Higgins
# 6                   AU Annual Leave      45.6   True  Dominique Higgins
# 7                        AU You Day       7.6   True  Dominique Higgins
# 8                   AU Annual Leave       7.6   True  Dominique Higgins
# 9         AU Sick and Carer's Leave       3.5    NaN  Dominique Higgins

# %%
leave_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10 entries, 0 to 9
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   EmployeeNumber  10 non-null     int64
#  1   DateofRequest   10 non-null     object
#  2   TimeStart       10 non-null     object
#  3   TimeEnd         10 non-null     object
#  4   TAFWXRefCode    1 non-null      object
#  5   LeaveType       10 non-null     object
#  6   NetHours        10 non-null     float64
#  7   AllDay          8 non-null      object
#  8   Full Name       10 non-null     object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 800.0+ bytes

# %%
leave_filtered['TimeStart'] = pd.to_datetime(leave_filtered['TimeStart'], errors='coerce')

# %%
leave_filtered
# Out:
#    EmployeeNumber        DateofRequest           TimeStart  \
# 0           80832  2025-06-25T12:56:00 2025-06-25 08:30:00
# 1           80832  2025-07-01T07:42:00 2025-09-15 00:00:00
# 2           80832  2025-07-09T09:39:00 2025-07-07 00:00:00
# 3           80832  2025-07-11T09:32:00 2025-11-14 00:00:00
# 4           80832  2025-07-16T17:08:00 2025-08-08 00:00:00
# 5           80185  2025-06-24T11:01:00 2025-06-27 00:00:00
# 6           80185  2025-07-21T10:25:00 2025-11-04 00:00:00
# 7           80185  2025-07-21T10:27:00 2025-08-08 00:00:00
# 8           80185  2025-07-21T10:30:00 2025-10-24 00:00:00
# 9           80185  2025-07-23T08:51:00 2025-07-22 13:00:00
#
#                TimeEnd                TAFWXRefCode  \
# 0  2025-06-25T11:00:00                         NaN
# 1  2025-09-20T00:00:00                         NaN
# 2  2025-07-09T00:00:00                         NaN
# 3  2025-11-22T00:00:00                         NaN
# 4  2025-08-09T00:00:00                         NaN
# 5  2025-06-28T00:00:00  80185_YOU_DAY_202506270000
# 6  2025-11-12T00:00:00                         NaN
# 7  2025-08-09T00:00:00                         NaN
# 8  2025-10-25T00:00:00                         NaN
# 9  2025-07-22T16:30:00                         NaN
#
#                           LeaveType  NetHours AllDay          Full Name
# 0         AU Sick and Carer's Leave       2.5    NaN   Hannah O'Connell
# 1  AU Unpaid Sick and Carer's Leave      38.0   True   Hannah O'Connell
# 2       AU Mandatory Training Leave      15.2   True   Hannah O'Connell
# 3                   AU Annual Leave      45.6   True   Hannah O'Connell
# 4                        AU You Day       7.6   True   Hannah O'Connell
# 5                        AU You Day       7.6   True  Dominique Higgins
# 6                   AU Annual Leave      45.6   True  Dominique Higgins
# 7                        AU You Day       7.6   True  Dominique Higgins
# 8                   AU Annual Leave       7.6   True  Dominique Higgins
# 9         AU Sick and Carer's Leave       3.5    NaN  Dominique Higgins

# %%
def keep_latest(df, id_col, time_col):
    return df.sort_values(time_col, ascending=False).drop_duplicates(id_col)

# %%
latest_leave = keep_latest(leave_filtered, id_col='EmployeeNumber', time_col='TimeStart')

# %%
latest_leave
# Out:
#    EmployeeNumber        DateofRequest  TimeStart              TimeEnd  \
# 3           80832  2025-07-11T09:32:00 2025-11-14  2025-11-22T00:00:00
# 6           80185  2025-07-21T10:25:00 2025-11-04  2025-11-12T00:00:00
#
#   TAFWXRefCode        LeaveType  NetHours AllDay          Full Name
# 3          NaN  AU Annual Leave      45.6   True   Hannah O'Connell
# 6          NaN  AU Annual Leave      45.6   True  Dominique Higgins

# %%
def keep_latest_this_month(df, id_col, time_col):
    # 获取当前年月
    current_year = pd.Timestamp.now().year
    current_month = pd.Timestamp.now().month

    # 过滤出本月的数据
    df_month = df[(df[time_col].dt.year == current_year) & (df[time_col].dt.month == current_month)]

    # 按时间降序排序并保留每个员工最新的一行
    return df_month.sort_values(time_col, ascending=False).drop_duplicates(id_col)

# %%
latest_leave_current_month = keep_latest_this_month(leave_filtered, id_col='EmployeeNumber', time_col='TimeStart')

# %%
latest_leave_current_month
# Out:
#    EmployeeNumber        DateofRequest  TimeStart              TimeEnd  \
# 4           80832  2025-07-16T17:08:00 2025-08-08  2025-08-09T00:00:00
# 7           80185  2025-07-21T10:27:00 2025-08-08  2025-08-09T00:00:00
#
#   TAFWXRefCode   LeaveType  NetHours AllDay          Full Name
# 4          NaN  AU You Day       7.6   True   Hannah O'Connell
# 7          NaN  AU You Day       7.6   True  Dominique Higgins
