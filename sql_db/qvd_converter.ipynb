# %%
import numpy as np
import pandas as pd
import os
from datetime import datetime
from dateutil.relativedelta import relativedelta
import re
import pyodbc

from pyqvd.qvd import QvdTable

# %%
# !python -m pip install pyqvd

# %%
import pyqvd
dir(pyqvd)
# Out:
# ['DateValue',
#  'DoubleValue',
#  'DualDoubleValue',
#  'DualIntegerValue',
#  'IntegerValue',
#  'IntervalValue',
#  'MoneyValue',
#  'QvdTable',
#  'QvdValue',
#  'StringValue',
#  'TimeValue',
#  'TimestampValue',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'qvd']

# %%
input_folder = r"\\prdeqs01\QlikData\Transform\LHC Snapshots"

# %%
qvd_path = os.path.join(input_folder, "LHC_SnapShot_20260220.qvd")

# %%
qvd = QvdTable.from_qvd(qvd_path)
df = qvd.to_pandas()

# %%
df
# Out:
#        Person ID  Membership ID Membership Status  member1_loading  \
# 0          14435          44675                 A                0
# 1          14436          44675                 A                0
# 2          14446          44679                 A                0
# 3          14447          44679                 A                0
# 4          14459          44684                 A                0
# ...          ...            ...               ...              ...
# 87628     448094         240616                 A                0
# 87629     448095         240616                 A                0
# 87630     448123         240624                 A                0
# 87631     448126         240626                 A                0
# 87632     448127         240626                 A                0
#
#        member2_loading status_flag  Relationship  Member Loading % Surname  \
# 0                    0           A             1               0.0  Sammut
# ...

# %%
df.columns
# Out:
# Index(['Person ID', 'Membership ID', 'Membership Status', 'member1_loading',
#        'member2_loading', 'status_flag', 'Relationship', 'Member Loading %',
#        'Surname', 'First Name', 'Other Names', 'Date of Birth', 'Age at Entry',
#        'lhc_entry_age_reason', 'LHC Been Removed', 'LHC Removal Date',
#        'SnapShot Date', 'Clearance Status', 'Days without Cover',
#        'Create Date'],
#       dtype='object')
