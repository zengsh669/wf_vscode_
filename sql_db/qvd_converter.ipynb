# %%
import numpy as np
import pandas as pd
import os
from datetime import datetime
from dateutil.relativedelta import relativedelta
import re
import pyodbc

from pyqvd.qvd import QvdTable

# %%
# !python -m pip install pyqvd

# %%
import pyqvd
dir(pyqvd)
# Out:
# ['DateValue',
#  'DoubleValue',
#  'DualDoubleValue',
#  'DualIntegerValue',
#  'IntegerValue',
#  'IntervalValue',
#  'MoneyValue',
#  'QvdTable',
#  'QvdValue',
#  'StringValue',
#  'TimeValue',
#  'TimestampValue',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'qvd']

# %%
input_folder = r"\\prdeqs01\QlikData\Transform\LHC Snapshots"

# %%
qvd_path = os.path.join(input_folder, "LHC_Daily_Movement.qvd")

# %%
qvd = QvdTable.from_qvd(qvd_path)
df = qvd.to_pandas()

# %%
df
# Out:
#        Person ID  Membership ID Membership Status  member1_loading  \
# 0          14435          44675                 A                0
# 1          14436          44675                 A                0
# 2          14446          44679                 A                0
# 3          14447          44679                 A                0
# 4          14459          44684                 A                0
# ...          ...            ...               ...              ...
# 87635     325628         190092                 A                0
# 87636      64415         190093                 A                0
# 87637     325663         190110                 A                0
# 87638     325664         190110                 A                0
# 87639      65621         190113                 A                0
#
#        member2_loading status_flag  Relationship  Member Loading %  \
# 0                    0           A             1               0.0
# 1                    0           A             2               0.0
# 2                    0           A             1               0.0
# 3                    0           A             2               0.0
# 4                    0           A             1               0.0
# ...                ...         ...           ...               ...
# 87635                0           A             2               0.0
# 87636                0           A             1               0.0
# 87637                0           A             1               0.0
# 87638                0           A             2               0.0
# 87639                0           A             1               0.0
#
#           Surname First Name Other Names Date of Birth  Age at Entry  \
# 0          Sammut   Kathleen        None    1964-03-14          30.0
# 1          Sammut      Peter        None    1963-08-28          30.0
# 2             Orr   Samantha       Jayne    1973-03-09          30.0
# 3             Orr     Robert       James    1966-12-23          30.0
# 4           Brown    Desmond      Sydney    1938-10-09          30.0
# ...           ...        ...         ...           ...           ...
# 87635      Moreau      Andre                1964-10-17          30.0
# 87636       Ahern    Rebecca                1995-12-11          30.0
# 87637  Thornberry     Roslyn                1956-02-02          30.0
# 87638  Thornberry      Kevin                1952-02-28          30.0
# 87639  Germanotta       Peta                1993-06-22          30.0
#
#        lhc_entry_age_reason LHC Been Removed LHC Removal Date SnapShot Date  \
# 0                       NaN                N             None    2026-03-03
# 1                       NaN                N             None    2026-03-03
# 2                       NaN                N             None    2026-03-03
# 3                       NaN                N             None    2026-03-03
# 4                       NaN                N             None    2026-03-03
# ...                     ...              ...              ...           ...
# 87635                   2.0                N             None    2026-03-03
# 87636                   NaN                N             None    2026-03-03
# 87637                   2.0                N             None    2026-03-03
# 87638                   2.0                N             None    2026-03-03
# 87639                   NaN                N             None    2026-03-03
#
#       Clearance Status  Days without Cover   Create Date
# 0                 None                 NaN  38078.913069
# 1                 None                 NaN  39612.645759
# 2                 None                 NaN  38078.913069
# 3                 None                 NaN  38078.911497
# 4                 None                 NaN  38078.913069
# ...                ...                 ...           ...
# 87635                R                 0.0  43685.412357
# 87636                H                 0.0  43685.446194
# 87637                R                 0.0  43685.591644
# 87638                R                 0.0  43685.591643
# 87639                H                 0.0  43769.741744
#
# [87640 rows x 20 columns]
